# %%
from Training.utils import load_results
results = load_results('checkpoints/results.json')

# %%
from Training.utils import visualize_results
metrics = ['loss','accuracy', 'precision', 'recall', 'f1_score']
visualize_results(metrics,results)
